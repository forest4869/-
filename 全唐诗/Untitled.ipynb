# %%
pip install pandas jieba
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: jieba in c:\users\苗\appdata\roaming\python\python39\site-packages (0.42.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import json
import re

# 1. 读取 JSON 文件
# 注意：你的文件看起来是多个对象的数组，但格式可能不标准。我们逐行读取。
with open('唐诗三百首.json', 'r', encoding='utf-8') as f:
    # 如果文件是标准的 JSON 数组，可以直接用 json.load(f)
    # 如果不标准，可以尝试逐行读取
    data = []
    for line in f:
        # 使用更健壮的方式清理引号
        line_clean = line.strip().replace('“', '"').replace('”', '"').replace('‘', "'").replace('’', "'")
        if line_clean: # 跳过空行
            try:
                data.append(json.loads(line_clean))
            except json.JSONDecodeError:
                print(f"跳过无法解析的行: {line_clean[:50]}...")
                continue

# 2. 转换为 DataFrame
df = pd.DataFrame(data)
print(f"原始数据量: {len(df)}")
print(df.head())

# 3. 数据清洗
# 清理正文：将段落列表合并成一个字符串
df['content'] = df['paragraphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')

# 简单的文本清理，去除空格和特殊字符
df['content'] = df['content'].str.replace(r'\s+', ' ', regex=True).str.strip()

# 4. 手动或半自动标注时期和题材
# 这是最耗时但最关键的一步。这里提供一个半自动化的思路。

# 时期映射字典 (需要你根据历史知识扩充)
period_mapping = {
    '骆宾王': '初唐',
    '陳子昂': '初唐',
    '明皇帝': '盛唐',
    # ... 继续添加其他诗人
}
df['period'] = df['author'].map(period_mapping)

# 题材映射 (可以从 tags 里提取，或者根据关键词)
# 例如，如果 tags 包含 "咏物"，则题材可以是 "咏物诗"
def infer_genre(tags_list):
    genre_keywords = {
        '山水': '山水田园诗',
        '田园': '山水田园诗',
        '咏物': '咏物诗',
        '边塞': '边塞诗',
        '送别': '送别诗',
        '怀古': '怀古诗',
        '爱情': '爱情诗',
        '政治': '政治诗'
    }
    for tag in tags_list:
        for keyword, genre in genre_keywords.items():
            if keyword in tag:
                return genre
    return '其他' # 默认值

df['genre'] = df['tags'].apply(infer_genre)

# 检查缺失值
print(f"时期缺失: {df['period'].isnull().sum()}")
print(f"题材缺失: {df['genre'].isnull().sum()}")

# 5. 保存清洗后的数据
df.to_csv('cleaned_tang_poems.csv', index=False, encoding='utf-8-sig')
print("数据清洗完成，已保存为 'cleaned_tang_poems.csv'")
# Out:
# 跳过无法解析的行: [...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "駱賓王",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "西陸蟬聲唱，南冠客思侵。",...
# 跳过无法解析的行: "那堪玄鬢影，來對白頭吟。",...
# 跳过无法解析的行: "露重飛難進，風多響易沈。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "咏物",...
# 跳过无法解析的行: "咏物诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "在嶽詠蟬",...
# 跳过无法解析的行: "id": "c65539db-4e2b-4ce4-a22b-563b6ef3f4f1"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "陳子昂",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "前不見古人，後不見來者。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "八年级下册(课外)",...
# 跳过无法解析的行: "伤怀",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "登幽州臺歌",...
# 跳过无法解析的行: "id": "c244a5b4-0ed0-48fe-8694-95309acac184"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "明皇帝",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "夫子何爲者？栖栖一代中。",...
# 跳过无法解析的行: "地猶鄹氏邑，宅即魯王宮。",...
# 跳过无法解析的行: "歎鳳嗟身否，傷麟怨道窮。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "伤怀",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "經鄒魯祭孔子而歎之",...
# 跳过无法解析的行: "id": "a1824eb8-4e2e-4d53-9a33-e1dcfe7d1c73"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "君不見黃河之水天上來，奔流到海不復回。",...
# 跳过无法解析的行: "君不見高堂明鏡悲白髮，朝如青絲暮成雪。",...
# 跳过无法解析的行: "人生得意須盡歡，莫使金尊空對月。",...
# 跳过无法解析的行: "天生我材必有用，千金散盡還復來。",...
# 跳过无法解析的行: "烹羊宰牛且爲樂，會須一飲三百杯。",...
# 跳过无法解析的行: "岑夫子，丹丘生，將進酒，杯莫停。",...
# 跳过无法解析的行: "與君歌一曲，請君爲我側耳聽。",...
# 跳过无法解析的行: "鐘鼓饌玉不足貴，但願長醉不復醒。",...
# 跳过无法解析的行: "古來聖賢皆寂寞，惟有飲者留其名。",...
# 跳过无法解析的行: "陳王昔時宴平樂，斗酒十千恣歡謔。",...
# 跳过无法解析的行: "主人何爲言少錢，徑須酤取對君酌。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "黄河",...
# 跳过无法解析的行: "咏物",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "鼓吹曲辞",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "宴饮",...
# 跳过无法解析的行: "哲理",...
# 跳过无法解析的行: "水",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "鼓吹曲辭 將進酒",...
# 跳过无法解析的行: "id": "0f7504df-cda2-4fe2-bc63-867ec2e418e7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王昌齡",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "秦時明月漢時關，萬里長征人未還。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "忧国忧民",...
# 跳过无法解析的行: "爱国",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "山",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "橫吹曲辭 出塞 一",...
# 跳过无法解析的行: "id": "2d0385e7-0c72-423f-a538-f66acc9d4c46"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王之渙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "黃砂直上白雲間，一片孤城萬仞山。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "橫吹曲辭 出塞",...
# 跳过无法解析的行: "id": "bcdf6f13-4cb9-418f-9279-c690522e0a27"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "明月出天山，蒼茫雲海間。",...
# 跳过无法解析的行: "長風幾萬里，吹度玉門關。",...
# 跳过无法解析的行: "漢下白登道，胡窺青海灣。",...
# 跳过无法解析的行: "由來征戰地，不見有人還。",...
# 跳过无法解析的行: "戍客望邊色，思歸多苦顏。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "中秋",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: "山",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "描写山",...
# 跳过无法解析的行: "写山",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "橫吹曲辭 關山月",...
# 跳过无法解析的行: "id": "0167687e-8325-48bf-8da4-3749c9ce0a74"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王建",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "三日入廚下，洗手作羹湯。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "新婚",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "新嫁娘詞三首 三",...
# 跳过无法解析的行: "id": "efaaa86e-5628-40d3-a137-1ae8fcbe41b8"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王建",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "寥落古行宮，宮花寂寞紅。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "怀古",...
# 跳过无法解析的行: "宫怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "故行宮",...
# 跳过无法解析的行: "id": "a6c85d29-ad02-4f54-a347-63800213a7b4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "錦瑟無端五十絃，一絃一柱思華年。",...
# 跳过无法解析的行: "莊生曉夢迷蝴蝶，望帝春心託杜鵑。",...
# 跳过无法解析的行: "滄海月明珠有淚，藍田日暖玉生煙。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "錦瑟",...
# 跳过无法解析的行: "id": "e0eb3016-9288-4dc0-9257-3de36e5ad73c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "本以高難飽，徒勞恨費聲。",...
# 跳过无法解析的行: "五更疎欲斷，一樹碧無情。",...
# 跳过无法解析的行: "薄宦梗猶汎，故園蕪已平。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "咏物",...
# 跳过无法解析的行: "咏物诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "蟬",...
# 跳过无法解析的行: "id": "b3de619f-cc8b-457d-942b-49f06651aba4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "向晚意不適，驅車登古原。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "惜时",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "樂遊原",...
# 跳过无法解析的行: "id": "d7c6d072-6e84-482e-856a-5a4c21226a3c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "君問歸期未有期，巴山夜雨漲秋池。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "写雨",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "景中情",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "高中古诗",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "爱情",...
# 跳过无法解析的行: "三年级上册",...
# 跳过无法解析的行: "雨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "夜雨寄北",...
# 跳过无法解析的行: "id": "75db753d-e7da-48a1-a6c0-6ed9147e58db"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "元和天子神武姿，彼何人哉軒與羲。",...
# 跳过无法解析的行: "誓將上雪列聖恥，坐法宮中朝四夷。",...
# 跳过无法解析的行: "淮西有賊五十載，封狼生貙貙生羆。",...
# 跳过无法解析的行: "不據山河據平地，長戈利矛日可麾。",...
# 跳过无法解析的行: "帝得聖相相曰度，賊斫不死神扶持。",...
# 跳过无法解析的行: "腰懸相印作都統，陰風慘澹天王旗。",...
# 跳过无法解析的行: "愬武古通作牙爪，儀曹外郎載筆隨。",...
# 跳过无法解析的行: "行軍司馬智且勇，十四萬衆猶虎貔。",...
# 跳过无法解析的行: "入蔡縛賊獻太廟，功無與讓恩不訾。",...
# 跳过无法解析的行: "帝曰汝度功第一，汝從事愈宜爲辭。",...
# 跳过无法解析的行: "愈拜稽首蹈且舞，金石刻畫臣能爲。",...
# 跳过无法解析的行: "古者世稱大手筆，此事不繫于職司。",...
# 跳过无法解析的行: "當仁自古有不讓，言訖屢頷天子頤。",...
# 跳过无法解析的行: "公退齋戒坐小閣，濡染大筆何淋漓。",...
# 跳过无法解析的行: "點竄堯典舜典字，塗改清廟生民詩。",...
# 跳过无法解析的行: "文成破體書在紙，清晨再拜鋪丹墀。",...
# 跳过无法解析的行: "表曰臣愈昧死上，詠神聖功書之碑。",...
# 跳过无法解析的行: "碑高三丈字如斗，負以靈鼇蟠以螭。",...
# 跳过无法解析的行: "句奇語重喻者少，讒之天子言其私。",...
# 跳过无法解析的行: "長繩百尺拽碑倒，麤砂大石相磨治。",...
# 跳过无法解析的行: "公之斯文若元氣，先時已入人肝脾。",...
# 跳过无法解析的行: "湯盤孔鼎有述作，今無其器存其辭。",...
# 跳过无法解析的行: "嗚呼聖皇及聖相，相與烜赫流淳熙。",...
# 跳过无法解析的行: "公之斯文不示後，曷與三五相攀追。",...
# 跳过无法解析的行: "願書萬本誦萬過，口角流沫右手胝。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "叙事",...
# 跳过无法解析的行: "七言古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "韓碑",...
# 跳过无法解析的行: "id": "0d2c5fba-d350-4c3f-b55e-72a491a84df6"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "淒涼寶劍篇，羈泊欲窮年。",...
# 跳过无法解析的行: "黃葉仍風雨，青樓自管絃。",...
# 跳过无法解析的行: "新知遭薄俗，舊好隔良緣。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "风雨",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "風雨",...
# 跳过无法解析的行: "id": "d32a2610-09d7-49ad-8cdf-dd9c649144c7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "嵩雲秦樹久離居，雙鯉迢迢一紙書。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "寄令狐郎中",...
# 跳过无法解析的行: "id": "fb376b71-91c6-44ee-b2e4-40f5b3f71b8f"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "紫泉宮殿鎖煙霞，欲取蕪城作帝家。",...
# 跳过无法解析的行: "玉璽不緣歸日角，錦帆應是到天涯。",...
# 跳过无法解析的行: "于今腐草無螢火，終古垂楊有暮鴉。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "讽刺",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "隋宮",...
# 跳过无法解析的行: "id": "670009c2-a701-4140-aa31-b4973f76d632"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "猿鳥猶疑畏簡書，風雲常爲護儲胥。",...
# 跳过无法解析的行: "徒令上將揮神筆，終見降王走傳車。",...
# 跳过无法解析的行: "管樂有才終不忝，關張無命欲何如。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "典故",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "籌筆驛",...
# 跳过无法解析的行: "id": "131c9f87-273f-4684-9b67-bd7b58ad4008"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "昨夜星辰昨夜風，畫樓西畔桂堂東。",...
# 跳过无法解析的行: "身無綵鳳雙飛翼，心有靈犀一點通。",...
# 跳过无法解析的行: "隔座送鉤春酒暖，分曹射覆蠟燈紅。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "宴饮",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "爱情",...
# 跳过无法解析的行: "相思",...
# 跳过无法解析的行: "感慨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題二首 一",...
# 跳过无法解析的行: "id": "3410e7ce-df3a-4ab8-bea3-7f681661b240"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "來是空言去絕踪，月斜樓上五更鐘。",...
# 跳过无法解析的行: "夢爲遠別啼難喚，書被催成墨未濃。",...
# 跳过无法解析的行: "蠟照半籠金翡翠，麝熏微度繡芙蓉。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "记梦",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題四首 一",...
# 跳过无法解析的行: "id": "7377e34a-1aab-47e3-a6dd-376c98a5d6b7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "颯颯東風細雨來，芙蓉塘外有輕雷。",...
# 跳过无法解析的行: "金蟾齧鏁燒香入，玉虎牽絲汲井迴。",...
# 跳过无法解析的行: "賈氏窺簾韓掾少，宓妃留枕魏王才。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "相思",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "爱情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題四首 二",...
# 跳过无法解析的行: "id": "811a5f9e-0df5-46f1-a587-0d4df7bca5a0"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "乘興南遊不戒嚴，九重誰省諫書函。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "咏史怀古",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "隋宮",...
# 跳过无法解析的行: "id": "91f95b30-c42f-470a-9df8-dd6284fca474"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "高閣客竟去，小園花亂飛。",...
# 跳过无法解析的行: "參差連曲陌，迢遰送斜暉。",...
# 跳过无法解析的行: "腸斷未忍掃，眼穿仍欲歸。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "咏物",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "写花",...
# 跳过无法解析的行: "抒怀",...
# 跳过无法解析的行: "花",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "落花",...
# 跳过无法解析的行: "id": "da157c27-d317-4205-9cdc-a254445659fc"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "爲有雲屏無限嬌，鳳城寒盡怕春宵。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "爲有",...
# 跳过无法解析的行: "id": "974914ee-1fc0-4952-a863-820bad2e4065"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "相見時難別亦難，東風無力百花殘。",...
# 跳过无法解析的行: "春蠶到死絲方盡，蠟炬成灰淚始乾。",...
# 跳过无法解析的行: "曉鏡但愁雲鬢改，夜吟應覺月光寒。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "八年级下册(课外)",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題",...
# 跳过无法解析的行: "id": "ed79f9bc-d5d1-4251-b22d-d091e0758a3f"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "瑤池阿母綺窗開，黃竹歌聲動地哀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "神话",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "瑤池",...
# 跳过无法解析的行: "id": "2161a569-6250-4886-9500-2168821b62be"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "悵臥新春白袷衣，白門寥落意多違。",...
# 跳过无法解析的行: "紅樓隔雨相望冷，珠箔飄燈獨自歸。",...
# 跳过无法解析的行: "遠路應悲春晼晚，殘宵猶得夢依稀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写雨",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "爱情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "春雨",...
# 跳过无法解析的行: "id": "8331c76b-a250-4d07-9c28-b8a456e0974c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "雲母屏風燭影深，長河漸落曉星沈。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "孤独",...
# 跳过无法解析的行: "中秋",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: "三年级下册",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "常娥",...
# 跳过无法解析的行: "id": "f7c9c409-9571-4eb8-abd9-91ec6c1ff564"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鳳尾香羅薄幾重，碧文圓頂夜深縫。",...
# 跳过无法解析的行: "扇裁月魄羞難掩，車走雷聲語未通。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題二首 一",...
# 跳过无法解析的行: "id": "e006dfd3-40be-40ef-ba3b-552428931ae3"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "重帷深下莫愁堂，臥後清宵細細長。",...
# 跳过无法解析的行: "神女生涯原是夢，小姑居處本無郎。",...
# 跳过无法解析的行: "風波不信菱枝弱，月露誰教桂葉香。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "無題二首 二",...
# 跳过无法解析的行: "id": "b6475dea-1d69-4f0d-b98a-39393f47741e"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "宣室求賢訪逐臣，賈生才調更無倫。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "托古讽今",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "賈生",...
# 跳过无法解析的行: "id": "02456f60-6ab5-4de8-b9ed-f7519818f0ca"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "客去波平檻，蟬休露滿枝。",...
# 跳过无法解析的行: "永懷當此節，倚立自移時。",...
# 跳过无法解析的行: "北斗兼春遠，南陵寓使遲。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "愁思",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "涼思",...
# 跳过无法解析的行: "id": "15c6cbc9-753a-4f09-86bf-4fe2d8bb1fee"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "殘陽西入崦，茅屋訪孤僧。",...
# 跳过无法解析的行: "落葉人何在，寒雲路幾層。",...
# 跳过无法解析的行: "獨敲初夜磬，閑倚一枝藤。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "寻访",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "北青蘿",...
# 跳过无法解析的行: "id": "9380d4f6-e19d-4ff1-8309-07f4ede69f7c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李商隱",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "折戟沈沙鐵未銷，自將磨洗認前朝。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "八年级下册(课内)",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "咏史怀古",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "赤壁",...
# 跳过无法解析的行: "id": "ae660471-84bc-4a58-a438-005b8a99c3c1"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韋莊",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "清瑟怨遙夜，遶弦風雨哀。",...
# 跳过无法解析的行: "孤燈聞楚角，殘月下章臺。",...
# 跳过无法解析的行: "芳草已云暮，故人殊未來。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "怀人",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "章臺夜思",...
# 跳过无法解析的行: "id": "19796737-ec7b-4c33-8df4-a81a7ca2cc10"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韋莊",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "誰謂傷心畫不成，畫人心逐世人情。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "题画",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "咏史怀古",...
# 跳过无法解析的行: "带有地名",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "金陵圖",...
# 跳过无法解析的行: "id": "4c5b328d-2ab8-4f4d-a0c2-627b6cb0c92b"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韋莊",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "江雨霏霏江草齊，六朝如夢鳥空啼。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "臺城",...
# 跳过无法解析的行: "id": "9154fc22-5e19-45b7-a506-435298bb26fc"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "薛逢",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "十二樓中盡曉妝，望仙樓上望君王。",...
# 跳过无法解析的行: "鎖銜金獸連環冷，水滴銅龍晝漏長。",...
# 跳过无法解析的行: "雲髻罷梳還對鏡，羅衣欲換更添香。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "宫怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "宮詞",...
# 跳过无法解析的行: "id": "f8d102c4-b25b-412f-afce-35db35c339d9"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "馬戴",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "露氣寒光集，微陽下楚丘。",...
# 跳过无法解析的行: "猨啼洞庭樹，人在木蘭舟。",...
# 跳过无法解析的行: "廣澤生明月，蒼山夾亂流。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "洞庭湖",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "楚江懷古三首 一",...
# 跳过无法解析的行: "id": "7456691c-636e-46d7-9093-edc778b0a7ea"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "馬戴",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "灞原風雨定，晚見鴈行頻。",...
# 跳过无法解析的行: "落葉他鄉樹，寒燈獨夜人。",...
# 跳过无法解析的行: "空園白露滴，孤壁野僧隣。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "孤独",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "灞上秋居",...
# 跳过无法解析的行: "id": "f2f04c30-149d-4b2b-bce1-1334adf84739"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "鄭畋",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "[玄]宗回馬楊妃死，雲雨雖亡日月新。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "带有地名",...
# 跳过无法解析的行: "咏史",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "馬嵬坡",...
# 跳过无法解析的行: "id": "7e75853a-bf7a-4d8d-b3e9-0537f4ed913a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "張籍",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "前年伐月支，城上沒全師。",...
# 跳过无法解析的行: "蕃漢斷消息，死生長別離。",...
# 跳过无法解析的行: "無人收廢帳，歸馬識殘旗。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "怀人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "沒蕃故人",...
# 跳过无法解析的行: "id": "5ccd5188-0e5d-450e-8ec5-d6e661fac4f7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "金昌緒",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "打起黃鶯兒，莫教枝上啼。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "怀人",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "春怨",...
# 跳过无法解析的行: "id": "b41e25f5-5a57-497f-a3a2-84bdfb9331f5"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "元稹",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "謝公最小偏憐女，嫁與黔婁百事乖。",...
# 跳过无法解析的行: "顧我無衣搜畫篋，泥他沽酒拔金釵。",...
# 跳过无法解析的行: "野蔬充膳甘長藿，落葉添薪仰古槐。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "遣悲懷三首 一",...
# 跳过无法解析的行: "id": "8b57e03d-6d1f-4a4a-ba34-1f58e2551ca1"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "元稹",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "昔日戲言身後意，今朝皆到眼前來。",...
# 跳过无法解析的行: "衣裳已施行看盡，針線猶存未忍開。",...
# 跳过无法解析的行: "尚想舊情憐婢僕，也曾因夢送錢財。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "追忆",...
# 跳过无法解析的行: "悼亡",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "遣悲懷三首 二",...
# 跳过无法解析的行: "id": "ea3f91f0-487e-4df7-826a-3692ef82e64d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "元稹",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "閑坐悲君亦自悲，百年都是幾多時。",...
# 跳过无法解析的行: "鄧攸無子尋知命，潘岳悼亡猶費詞。",...
# 跳过无法解析的行: "同穴窅冥何所望，他生緣會更難期。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "遣悲懷三首 三",...
# 跳过无法解析的行: "id": "82f57261-b608-4ee9-8d88-7fde20c49a7a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "元稹",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "寥落古行宮，宮花寂寞紅。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "怀古",...
# 跳过无法解析的行: "宫怨",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "行宮",...
# 跳过无法解析的行: "id": "02943f6d-2c91-4d9c-9690-247eab9ae3ec"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "西鄙人",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "北斗七星高，哥舒夜帶刀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "赞颂",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "哥舒歌",...
# 跳过无法解析的行: "id": "ac2ec0ba-10b1-4ae3-8859-1e7752625331"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "無名氏",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "近寒食雨草萋萋，著麥苗風柳映堤。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "寒食节",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜詩 十三",...
# 跳过无法解析的行: "id": "31e9a6b0-5035-4b1b-a9d3-ff1c279f53b6"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "沈佺期",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "聞道黃龍戍，頻年不解兵。",...
# 跳过无法解析的行: "可憐閨裏月，長在漢家營。",...
# 跳过无法解析的行: "少婦今春意，良人昨夜情。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜詩三首 三",...
# 跳过无法解析的行: "id": "1fb10ea4-f46c-4c08-bd06-f039f1907be6"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "沈佺期",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "盧家少婦鬱金堂，海燕雙棲玳瑁梁。",...
# 跳过无法解析的行: "九月寒砧催木葉，十年征戍憶遼陽。",...
# 跳过无法解析的行: "白狼河北音書斷，丹鳳城南秋夜長。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "闺怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "古意呈補闕喬知之",...
# 跳过无法解析的行: "id": "b9521e2b-963e-4d90-acf3-d87c2a135071"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王灣",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "客路青山外，行舟綠水前。",...
# 跳过无法解析的行: "潮平兩岸闊，風正一帆懸。",...
# 跳过无法解析的行: "海日生殘夜，江春入舊年。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七年级上册(课内)",...
# 跳过无法解析的行: "地点",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "哲理",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "次北固山下",...
# 跳过无法解析的行: "id": "5bb5c590-5de8-4bfb-aee6-30bc4bcdf99a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "張旭",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "隱隱飛橋隔野煙，石磯西畔問漁船。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "描写水",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "桃花谿",...
# 跳过无法解析的行: "id": "1f28ab03-8388-4a2f-8c4f-3ce47789e221"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "下馬飲君酒，問君何所之。",...
# 跳过无法解析的行: "君言不得意，歸臥南山陲。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送別",...
# 跳过无法解析的行: "id": "31cc87f3-da0f-421d-8674-8753530077e2"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "聖代無隱者，英靈盡來歸。",...
# 跳过无法解析的行: "遂令東山客，不得顧采薇。",...
# 跳过无法解析的行: "既至君門遠，孰云吾道非。",...
# 跳过无法解析的行: "江淮度寒食，京洛縫春衣。",...
# 跳过无法解析的行: "置酒臨長道，同心與我違。",...
# 跳过无法解析的行: "行當浮桂櫂，未幾拂荆扉。",...
# 跳过无法解析的行: "遠樹帶行客，孤村當落暉。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "慰勉",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送綦毋潛落第還鄉",...
# 跳过无法解析的行: "id": "56bec3c2-9c0c-4d40-9750-2e28bdc9a20e"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "言入黃花川，每逐青谿水。",...
# 跳过无法解析的行: "隨山將萬轉，趣途無百里。",...
# 跳过无法解析的行: "聲喧亂石中，色靜深松裏。",...
# 跳过无法解析的行: "漾漾汎菱荇，澄澄映葭葦。",...
# 跳过无法解析的行: "我心素已閑，清川澹如此。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "托物寄情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "青谿",...
# 跳过无法解析的行: "id": "a0576d39-c4ac-4608-a4e2-249b6c31fd1d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "斜陽照墟落，窮巷牛羊歸。",...
# 跳过无法解析的行: "野老念牧童，倚杖候荆扉。",...
# 跳过无法解析的行: "雉雊麥苗秀，蠶眠桑葉稀。",...
# 跳过无法解析的行: "田夫荷鋤至，相見語依依。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "归隐",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "渭川田家",...
# 跳过无法解析的行: "id": "204e287b-8194-4c2d-808b-11cc260412ae"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "豔色天下重，西施寧久微。",...
# 跳过无法解析的行: "朝仍越溪女，暮作吳宮妃。",...
# 跳过无法解析的行: "賤日豈殊衆，貴來方悟稀。",...
# 跳过无法解析的行: "邀人傅香粉，不自著羅衣。",...
# 跳过无法解析的行: "君寵益嬌態，君憐無是非。",...
# 跳过无法解析的行: "當時浣紗伴，莫得同車歸。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "怀古",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "西施詠",...
# 跳过无法解析的行: "id": "4d6f83e9-8232-4db1-903e-f9e619df5ecb"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "少年十五二十時，步行奪得胡馬射。",...
# 跳过无法解析的行: "射殺中山白額虎，肯數鄴下黃鬚兒。",...
# 跳过无法解析的行: "一身轉戰三千里，一劒曾當百萬師。",...
# 跳过无法解析的行: "漢兵奮迅如霹靂，虜騎崩騰畏蒺藜。",...
# 跳过无法解析的行: "衞青不敗由天幸，李廣無功緣數奇。",...
# 跳过无法解析的行: "自從棄置便衰朽，世事磋跎成白首。",...
# 跳过无法解析的行: "昔時飛箭無全目，今日垂楊生左肘。",...
# 跳过无法解析的行: "路傍時賣故侯瓜，門前學種先生柳。",...
# 跳过无法解析的行: "蒼茫古木連窮巷，寥落寒山對虛牖。",...
# 跳过无法解析的行: "誓令疏勒出飛泉，不似潁川空使酒。",...
# 跳过无法解析的行: "賀蘭山下陣如雲，羽檄交馳日夕聞。",...
# 跳过无法解析的行: "節使三河募年少，詔書五道出將軍。",...
# 跳过无法解析的行: "試拂鐵衣如雪色，聊持寶劒動星文。",...
# 跳过无法解析的行: "願得燕弓射天將，恥令越甲鳴吳軍。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: "新乐府辞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "老將行",...
# 跳过无法解析的行: "id": "d5d66aff-b6ae-48cc-9160-16b096d4ea49"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "漁舟逐水愛山春，兩岸桃花夾去津。",...
# 跳过无法解析的行: "坐看紅樹不知遠，行盡青溪不見人。",...
# 跳过无法解析的行: "山口潛行始隈隩，山開曠望旋平陸。",...
# 跳过无法解析的行: "遙看一處攢雲樹，近入千家散花竹。",...
# 跳过无法解析的行: "樵客初傳漢姓名，居人未改秦衣服。",...
# 跳过无法解析的行: "居人共住武陵源，還從物外起田園。",...
# 跳过无法解析的行: "月明松下房櫳靜，日出雲中雞犬喧。",...
# 跳过无法解析的行: "驚聞俗客爭來集，競引還家問都邑。",...
# 跳过无法解析的行: "平明閭巷埽花開，薄暮漁樵乘水入。",...
# 跳过无法解析的行: "初因避地去人間，及至成仙遂不還。",...
# 跳过无法解析的行: "峽裏誰知有人事，世中遙望空雲山。",...
# 跳过无法解析的行: "不疑靈境難聞見，塵心未盡思鄉縣。",...
# 跳过无法解析的行: "出洞無論隔山水，辭家終擬長游衍。",...
# 跳过无法解析的行: "自謂經過舊不迷，安知峰壑今來變。",...
# 跳过无法解析的行: "當時只記入山深，青溪幾曲到雲林。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "新乐府辞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "桃源行",...
# 跳过无法解析的行: "id": "3b847cf5-16b1-449d-a436-e5995c6433c4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "洛陽女兒對門居，纔可容顏十五餘。",...
# 跳过无法解析的行: "良人玉勒乘驄馬，侍女金盤鱠鯉魚。",...
# 跳过无法解析的行: "畫閣朱樓盡相望，紅桃綠柳垂簷向。",...
# 跳过无法解析的行: "羅幃送上七香車，寶扇迎歸九華帳。",...
# 跳过无法解析的行: "狂夫富貴在青春，意氣驕奢劇季倫。",...
# 跳过无法解析的行: "自憐碧玉親教舞，不惜珊瑚持與人。",...
# 跳过无法解析的行: "春窗曙滅九微火，九微片片飛花璅。",...
# 跳过无法解析的行: "戲罷曾無理曲時，妝成秪是薰香坐。",...
# 跳过无法解析的行: "城中相識盡繁華，日夜經過趙李家。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "生活",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "洛陽女兒行",...
# 跳过无法解析的行: "id": "4925c861-b0f8-4b2f-923e-9cba2df1323e"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "寒山轉蒼翠，秋水日潺湲。",...
# 跳过无法解析的行: "倚杖柴門外，臨風聽暮蟬。",...
# 跳过无法解析的行: "渡頭餘落日，墟里上孤煙。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "輞川閑居贈裴秀才迪",...
# 跳过无法解析的行: "id": "a2b4e8ca-92e3-4101-8a54-739b8f1d8184"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "晚年唯好靜，萬事不關心。",...
# 跳过无法解析的行: "自顧無長策，空知返舊林。",...
# 跳过无法解析的行: "松風吹解帶，山月照彈琴。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "赠别",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "规劝",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "酬張少府",...
# 跳过无法解析的行: "id": "65e9c24b-bdbd-4ef9-9e14-012c8fde79b8"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "萬壑樹參天，千山響杜鵑。",...
# 跳过无法解析的行: "山中一夜雨，樹杪百重泉。",...
# 跳过无法解析的行: "漢女輸橦布，巴人訟芋田。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送梓州李使君",...
# 跳过无法解析的行: "id": "263b4a33-fd51-47e1-b49a-d84dd99a2e0f"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "權德輿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "昨夜裙帶解，今朝蟢子飛。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "玉臺體十二首 十一",...
# 跳过无法解析的行: "id": "9a5070c8-8b6a-46d3-a976-ce942baf42e7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韓愈",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "山石犖確行徑微，黃昏到寺蝙蝠飛。",...
# 跳过无法解析的行: "升堂坐階新雨足，芭蕉葉大支子肥。",...
# 跳过无法解析的行: "僧言古壁佛畫好，以火來照所見稀。",...
# 跳过无法解析的行: "鋪牀拂席置羹飯，疎糲亦足飽我飢。",...
# 跳过无法解析的行: "夜深靜臥百蟲絕，清月出嶺光入扉。",...
# 跳过无法解析的行: "天明獨去無道路，出入高下窮煙霏。",...
# 跳过无法解析的行: "山紅澗碧紛爛漫，時見松櫪皆十圍。",...
# 跳过无法解析的行: "當流赤足蹋澗石，水聲激激風吹衣。",...
# 跳过无法解析的行: "人生如此自可樂，豈必局束爲人鞿。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "纪游",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "山石",...
# 跳过无法解析的行: "id": "e73e2743-3752-4ba3-938a-fb59cd3965ee"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韓愈",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "纖雲四卷天無河，清風吹空月舒波。",...
# 跳过无法解析的行: "沙平水息聲影絕，一桮相屬君當歌。",...
# 跳过无法解析的行: "君歌聲酸辭且苦，不能聽終淚如雨。",...
# 跳过无法解析的行: "洞庭連天九疑高，蛟龍出沒猩鼯號。",...
# 跳过无法解析的行: "十生九死到官所，幽居默默如藏逃。",...
# 跳过无法解析的行: "下牀畏蛇食畏藥，海氣濕蟄熏腥臊。",...
# 跳过无法解析的行: "昨者州前搥大鼓，嗣皇繼聖登夔臯。",...
# 跳过无法解析的行: "赦書一日行萬里，罪從大辟皆除死。",...
# 跳过无法解析的行: "遷者追廻流者還，滌瑕蕩垢清朝班。",...
# 跳过无法解析的行: "州家申名使家抑，坎軻祗得移荆蠻。",...
# 跳过无法解析的行: "判司卑官不堪說，未免捶楚塵埃間。",...
# 跳过无法解析的行: "同時輩流多上道，天路幽險難追攀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "洞庭湖",...
# 跳过无法解析的行: "中秋节",...
# 跳过无法解析的行: "七言古诗",...
# 跳过无法解析的行: "抒怀",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "八月十五夜贈張功曹",...
# 跳过无法解析的行: "id": "88e98bed-27fa-4dbe-8d6e-e7cb8c3e4d97"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韓愈",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "五嶽祭秩皆三公，四方環鎮嵩當中。",...
# 跳过无法解析的行: "火維地荒足妖怪，天假神柄專其雄。",...
# 跳过无法解析的行: "噴雲泄霧藏半腹，雖有絕頂誰能窮。",...
# 跳过无法解析的行: "我來正逢秋雨節，陰氣晦昧無清風。",...
# 跳过无法解析的行: "潛心默禱若有應，豈非正直能感通。",...
# 跳过无法解析的行: "須臾靜掃衆峰出，仰見突兀撐青空。",...
# 跳过无法解析的行: "紫蓋連延接天柱，石廩騰擲堆祝融。",...
# 跳过无法解析的行: "森然魄動下馬拜，松柏一逕趨靈宮。",...
# 跳过无法解析的行: "粉牆丹柱動光彩，鬼物圖畫填青紅。",...
# 跳过无法解析的行: "升階傴僂薦脯酒，欲以菲薄明其衷。",...
# 跳过无法解析的行: "廟令老人識神意，睢盱偵伺能鞠躬。",...
# 跳过无法解析的行: "手持桮珓導我擲，云此最吉餘難同。",...
# 跳过无法解析的行: "竄逐蠻荒幸不死，衣食纔足甘長終。",...
# 跳过无法解析的行: "侯王將相望久絕，神縱欲福難爲功。",...
# 跳过无法解析的行: "夜投佛寺上高閣，星月掩暎雲朣朧。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "登高",...
# 跳过无法解析的行: "七言古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "謁衡嶽廟遂宿嶽寺題門樓",...
# 跳过无法解析的行: "id": "14ae27a0-2641-41e6-8c0a-60a9185f8b6d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韓偓",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "碧闌干外繡簾垂，猩血屏風畫折枝。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "爱情",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "已涼",...
# 跳过无法解析的行: "id": "1deac6d5-6da0-4d9f-a182-2f0697cbb932"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜荀鶴",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "早被嬋娟誤，欲妝臨鏡慵。",...
# 跳过无法解析的行: "承恩不在貌，教妾若爲容。",...
# 跳过无法解析的行: "風暖鳥聲碎，日高花影重。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "宫怨",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "春宮怨",...
# 跳过无法解析的行: "id": "8eaf97fd-82bb-4651-9dde-9a5a6f78182c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "朱慶餘",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "洞房昨夜停紅燭，待曉堂前拜舅姑。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "新婚",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "近試上張籍水部",...
# 跳过无法解析的行: "id": "27ff54ab-4861-43d8-b3c1-69113d2e4e10"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "清時有味是無能，閑愛孤雲靜愛僧。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "將赴吳興登樂遊原一絕",...
# 跳过无法解析的行: "id": "24ca9268-9cbd-423b-b423-12e1a9aa9041"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "折戟沈沙鐵未銷，自將磨洗認前朝。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "八年级下册(课内)",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "咏史怀古",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "赤壁",...
# 跳过无法解析的行: "id": "7c93c162-d424-4d91-b71b-7c9b81713b8c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "煙籠寒水月籠沙，夜泊秦淮近酒家。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: "爱国",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "抒怀",...
# 跳过无法解析的行: "咏史怀古",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "泊秦淮",...
# 跳过无法解析的行: "id": "8de30193-fba7-4aef-9ff9-c3726a22104d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "娉娉褭褭十三餘，豆蔻梢頭二月初。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "贈別二首 一",...
# 跳过无法解析的行: "id": "54008cd0-f9bf-424f-bc55-f15c1e9025f3"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "多情却似總無情，唯覺尊前笑不成。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "离别",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "贈別二首 二",...
# 跳过无法解析的行: "id": "a7f425de-143b-493d-bb51-13e27c68e871"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "落魄江南載酒行，楚腰腸斷掌中輕。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "遣懷",...
# 跳过无法解析的行: "id": "92ae04dc-89af-45d6-9e31-204a01df801d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "紅燭秋光冷畫屏，輕羅小扇撲流螢。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "秋夕",...
# 跳过无法解析的行: "id": "d12edd29-d467-4b19-b3f5-533fa5c8d56a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "繁華事散逐香塵，流水無情草自春。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "金谷園",...
# 跳过无法解析的行: "id": "80159919-0b66-4956-a563-ef9bcf6a05c0"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜牧",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "旅館無良伴，凝情自悄然。",...
# 跳过无法解析的行: "寒燈思舊事，斷鴈警愁眠。",...
# 跳过无法解析的行: "遠夢歸侵曉，家書到隔年。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "羁旅",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "旅宿",...
# 跳过无法解析的行: "id": "200fe9fa-0221-4123-86de-4d63ce9d3daf"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "許渾",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "遙夜泛清瑟，西風生翠蘿。",...
# 跳过无法解析的行: "殘螢委玉露，早鴈拂銀河。",...
# 跳过无法解析的行: "高樹曉還密，遠山晴更多。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "早秋三首 一",...
# 跳过无法解析的行: "id": "fedb06cc-37da-4aaf-8f39-85ebcb08b947"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "許渾",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "紅葉晚蕭蕭，長亭酒一瓢。",...
# 跳过无法解析的行: "殘雲歸太華，疎雨過中條。",...
# 跳过无法解析的行: "樹色隨山迥，河聲入海遙。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "秋日赴闕題潼關驛樓",...
# 跳过无法解析的行: "id": "292c14cd-151f-4321-a94c-46fc86693eb3"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "張泌",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "別夢依依到謝家，小廊迴合曲闌斜。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: "月亮",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "寄人 一",...
# 跳过无法解析的行: "id": "afc2e6d6-e67f-4513-a6ab-82841d2f97cc"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "陳陶",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "誓掃匈奴不顧身，五千貂錦喪胡塵。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "隴西行四首 二",...
# 跳过无法解析的行: "id": "fde30eaa-9b2c-47ce-ba49-c1356353ac9a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "釋明辯",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "打起黄鶯兒，莫教枝上啼。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "怀人",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: "闺怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "頌古三十二首  其二三",...
# 跳过无法解析的行: "id": "228c87f2-092b-411b-9029-c5454cc2cb1c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "白居易",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "淚濕羅巾夢不成，夜深前殿按歌聲。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "後宮詞",...
# 跳过无法解析的行: "id": "549a5a94-a8f5-436e-bc9c-1253d01c1940"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李益",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "十年離亂後，長大一相逢。",...
# 跳过无法解析的行: "問姓驚初見，稱名憶舊容。",...
# 跳过无法解析的行: "別來滄海事，語罷暮天鐘。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "离别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "喜見外弟又言別",...
# 跳过无法解析的行: "id": "d755f74b-18fd-44d1-a6e1-43e77490bb09"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李益",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "嫁得瞿塘賈，朝朝悞妾期。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "闺怨",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "江南詞",...
# 跳过无法解析的行: "id": "9bd49546-5289-4351-97f4-d69296720dfc"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李益",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "回樂峰前沙似雪，受降城下月如霜。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "冬天",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "夜上受降城聞笛",...
# 跳过无法解析的行: "id": "992df222-c445-4925-a656-0caa4447d5bb"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李端",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鳴箏金粟柱，素手玉房前。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "聽箏",...
# 跳过无法解析的行: "id": "7f3799de-78b4-49bc-b6d8-a5fa3ecacd33"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "司空曙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "世亂同南去，時清獨北還。",...
# 跳过无法解析的行: "他鄉生白髮，舊國見青山。",...
# 跳过无法解析的行: "曉月過殘壘，繁星宿故關。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "酬赠",...
# 跳过无法解析的行: "感伤",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "賊平後送人北歸",...
# 跳过无法解析的行: "id": "4c745990-657a-41fe-ba2c-d9cf371ca563"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "司空曙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "故人江海別，幾度隔山川。",...
# 跳过无法解析的行: "乍見翻疑夢，相悲各問年。",...
# 跳过无法解析的行: "孤燈寒照雨，溼竹暗浮煙。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雲陽館與韓紳宿別",...
# 跳过无法解析的行: "id": "3138fe30-6cf6-45b0-a441-2d5398107a9a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "司空曙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "靜夜四無鄰，荒居舊業貧。",...
# 跳过无法解析的行: "雨中黃葉樹，燈下白頭人。",...
# 跳过无法解析的行: "以我獨沈久，愧君相見頻。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "生活",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "喜外弟盧綸見宿",...
# 跳过无法解析的行: "id": "f0cd6afd-c89d-4fc3-b214-bcbf63042e8e"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "泠泠七絲上，靜聽松風寒。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "音乐",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "聽彈琴",...
# 跳过无法解析的行: "id": "72aab9ef-65a9-4a8a-b36b-61932c09ce85"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "孤雲將野鶴，豈向人間住。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送方外上人",...
# 跳过无法解析的行: "id": "c26445b5-a433-4cd7-9020-435866b845f9"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "蒼蒼竹林寺，杳杳鐘聲晚。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "即景抒情",...
# 跳过无法解析的行: "五言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送靈澈上人",...
# 跳过无法解析的行: "id": "a746d1f0-a72c-44d2-8b1c-c5c990749257"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鄉心新歲切，天畔獨潸然。",...
# 跳过无法解析的行: "老至居人下，春歸在客先。",...
# 跳过无法解析的行: "嶺猨同旦暮，江柳共風煙。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "春节",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "新年作",...
# 跳过无法解析的行: "id": "6556f501-f5b9-4353-bde2-75ec0e1bb616"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "古臺搖落後，秋日望鄉心。",...
# 跳过无法解析的行: "野寺人來少，雲峰水隔深。",...
# 跳过无法解析的行: "夕陽依舊壘，寒磬滿空林。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "长江",...
# 跳过无法解析的行: "怀古",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "秋日登吳公臺上寺遠眺寺即陳將吳明徹戰場",...
# 跳过无法解析的行: "id": "fdc07d9f-95b8-45f7-b1b3-9d272b3416a4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "一路經行處，莓苔見履痕。",...
# 跳过无法解析的行: "白雲依靜渚，春草閉閑門。",...
# 跳过无法解析的行: "過雨看松色，隨山到水源。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "尋南溪常山道人隱居",...
# 跳过无法解析的行: "id": "04af557e-bac8-4fbf-92e7-d8a87fa11038"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "望君煙水闊，揮手淚霑巾。",...
# 跳过无法解析的行: "飛鳥沒何處，青山空向人。",...
# 跳过无法解析的行: "長江一帆遠，落日五湖春。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "长江",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "餞別王十一南遊",...
# 跳过无法解析的行: "id": "1487452b-5f49-4f4f-9913-1f3ec1cddf95"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "生涯豈料承優詔，世事空知學醉歌。",...
# 跳过无法解析的行: "江上月明胡鴈過，淮南木落楚山多。",...
# 跳过无法解析的行: "寄身且喜滄洲近，顧影無如白髮何。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "江州重別薛六柳八二員外",...
# 跳过无法解析的行: "id": "d9dd3520-9aab-4b1b-bd57-810f29391667"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "三年謫宦此棲遲，萬古惟留楚客悲。",...
# 跳过无法解析的行: "秋草獨尋人去後，寒林空見日斜時。",...
# 跳过无法解析的行: "漢文有道恩猶薄，湘水無情弔豈知。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "迁谪",...
# 跳过无法解析的行: "生活",...
# 跳过无法解析的行: "怀古",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "長沙過賈誼宅",...
# 跳过无法解析的行: "id": "8cefa67f-2b9a-4e13-8158-4d38cbfb331b"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "[汀]洲無浪復無煙，楚客相思益渺然。",...
# 跳过无法解析的行: "漢口夕陽斜渡鳥，洞庭秋水遠連天。",...
# 跳过无法解析的行: "孤城背嶺寒吹角，獨戍臨江夜泊船。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "洞庭湖",...
# 跳过无法解析的行: "贬谪",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "自夏口至鸚鵡洲夕望岳陽寄源中丞",...
# 跳过无法解析的行: "id": "3f049d66-1513-407f-bb4e-cf25a7b5069a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉長卿",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鶯啼燕語報新年，馬邑龍堆路幾千。",...
# 跳过无法解析的行: "家住層城臨漢苑，[心]隨明月到胡天。",...
# 跳过无法解析的行: "機中錦字論長恨，樓上花枝笑獨眠。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "賦得",...
# 跳过无法解析的行: "id": "41d292d2-b752-4c30-8b6b-7b7380f2f9bd"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "崔曙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "漢文皇帝有高臺，此日登臨曙色開。",...
# 跳过无法解析的行: "三晉雲山皆北向，二陵風雨自東來。",...
# 跳过无法解析的行: "關門令尹誰能識，河上仙翁去不回。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "登高",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "九日登望仙臺呈劉明府容",...
# 跳过无法解析的行: "id": "1c1d545e-07a1-46a9-bb76-b7473c1fde43"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王翰",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "葡萄美酒夜光杯，欲飲琵琶馬上催。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "豪放",...
# 跳过无法解析的行: "战争",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: "宴饮",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "涼州詞二首 一",...
# 跳过无法解析的行: "id": "0445f296-5816-4ab9-a617-7d8ed29088ea"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "北山白雲裏，隱者自怡悅。",...
# 跳过无法解析的行: "相望試登高，心飛逐鳥滅。",...
# 跳过无法解析的行: "愁因薄暮起，興是清秋發。",...
# 跳过无法解析的行: "時見歸村人，沙行渡頭歇。",...
# 跳过无法解析的行: "天邊樹若薺，江畔舟如月。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: "登高",...
# 跳过无法解析的行: "山",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "秋登蘭山寄張五",...
# 跳过无法解析的行: "id": "56ca5b29-4bb9-4f12-9200-6bc7c72e4e47"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "山光忽西落，池月漸東上。",...
# 跳过无法解析的行: "散髮乘夕涼，開軒臥閑敞。",...
# 跳过无法解析的行: "荷風送香氣，竹露滴清響。",...
# 跳过无法解析的行: "欲取鳴琴彈，恨無知音賞。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "夏天",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "夏日南亭懷辛大",...
# 跳过无法解析的行: "id": "f8afed4e-e8cd-467f-afae-51dc149921f7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "夕陽度西嶺，羣壑倏已暝。",...
# 跳过无法解析的行: "松月生夜涼，風泉滿清聽。",...
# 跳过无法解析的行: "樵人歸欲盡，煙鳥棲初定。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "宿業師山房期丁大不至",...
# 跳过无法解析的行: "id": "3e504df9-b22d-480e-9e7c-9f8ab8591b91"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "山寺鐘鳴晝已昏，漁梁渡頭爭渡喧。",...
# 跳过无法解析的行: "人隨沙路向江村，余亦乘舟歸鹿門。",...
# 跳过无法解析的行: "鹿門月照開煙樹，忽到龐公棲隱處。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "归隐",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "夜歸鹿門山歌",...
# 跳过无法解析的行: "id": "cc0e7ac3-bde4-4491-8ae5-027106709e72"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "八月湖水平，涵虛混太清。",...
# 跳过无法解析的行: "氣蒸雲夢澤，波撼岳陽城。",...
# 跳过无法解析的行: "欲濟無舟楫，端居恥聖明。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "洞庭湖",...
# 跳过无法解析的行: "描写水",...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "八年级上册(课外)",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "水",...
# 跳过无法解析的行: "带有地名",...
# 跳过无法解析的行: "写水",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "望洞庭湖贈張丞相",...
# 跳过无法解析的行: "id": "6975adab-25d0-40c6-af3a-3a05847e7717"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "一丘常欲臥，三徑苦無資。",...
# 跳过无法解析的行: "北土非吾願，東林懷我師。",...
# 跳过无法解析的行: "黃金然桂盡，壯志逐年衰。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "归隐",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "秦中感秋寄遠上人",...
# 跳过无法解析的行: "id": "0613f575-4f07-4326-8591-603fb3d1da45"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "山暝聞猿愁，滄江急夜流。",...
# 跳过无法解析的行: "風鳴兩岸葉，月照一孤舟。",...
# 跳过无法解析的行: "建德非吾土，維揚憶舊遊。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "描写水",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "怀人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "宿桐廬江寄廣陵舊遊",...
# 跳过无法解析的行: "id": "b1dad78c-4dd8-4b99-b37b-741ed761f26a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "木落雁南度，北風江上寒。",...
# 跳过无法解析的行: "我家襄水上，遙隔楚雲端。",...
# 跳过无法解析的行: "鄉淚客中盡，孤帆天際看。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "八年级上册(课外)",...
# 跳过无法解析的行: "思归",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "早寒江上有懷",...
# 跳过无法解析的行: "id": "8e18183e-5a58-4805-b672-1726969d6526"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "寂寂竟何待，朝朝空自歸。",...
# 跳过无法解析的行: "欲尋芳草去，惜與故人違。",...
# 跳过无法解析的行: "當路誰相假，知音世所稀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "归隐",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "离别",...
# 跳过无法解析的行: "哀怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "留別王侍御維",...
# 跳过无法解析的行: "id": "7f4cacb5-cde8-40de-9b14-e223879cc2f4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "林臥愁春盡，開軒覽物華。",...
# 跳过无法解析的行: "忽逢青鳥使，邀入赤松家。",...
# 跳过无法解析的行: "丹竈初開火，仙桃正落花。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "清明日宴梅道士房",...
# 跳过无法解析的行: "id": "d2b5090e-e6fe-4d4f-9dd6-fe94ff6d4b5c"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "人事有代謝，往來成古今。",...
# 跳过无法解析的行: "江山留勝跡，我輩復登臨。",...
# 跳过无法解析的行: "水落魚梁淺，天寒夢澤深。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "吊古伤今",...
# 跳过无法解析的行: "隋・唐・五代",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "與諸子登峴山",...
# 跳过无法解析的行: "id": "b71d7c9c-7e92-4797-b2c9-8715dd0c2881"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟浩然",...
# 跳过无法解析的行: "paragraphs": [...
# ...
# 跳过无法解析的行: "吳中盛文史，羣彥今汪洋。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "郡齋雨中與諸文士燕集",...
# 跳过无法解析的行: "id": "9f5ded08-4f6f-4641-878e-897904483479"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "韋應物",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "悽悽去親愛，泛泛入煙霧。",...
# 跳过无法解析的行: "歸棹洛陽人，殘鐘廣陵樹。",...
# 跳过无法解析的行: "今朝此爲別，何處還相遇。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "离别",...
# 跳过无法解析的行: "五言古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "初發揚子寄元大校書",...
# 跳过无法解析的行: "id": "5b3a5651-2a80-4fb1-b1bf-c9fb5ec38905"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李益",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "嫁得瞿塘賈，朝朝誤妾期。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "闺怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 江南曲",...
# 跳过无法解析的行: "id": "bb111748-d8f1-4a5e-b618-b70272a7a642"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "高適",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "漢家煙塵在東北，漢將辭家破殘賊。",...
# 跳过无法解析的行: "男兒本自重橫行，天子非常賜顏色。",...
# 跳过无法解析的行: "摐金伐鼓下榆關，旌旗逶迤碣石間。",...
# 跳过无法解析的行: "校尉羽書飛瀚海，單于獵火照狼山。",...
# 跳过无法解析的行: "山川蕭條極邊土，胡騎憑凌雜風雨。",...
# 跳过无法解析的行: "戰士軍前半死生，美人帳下猶歌舞。",...
# 跳过无法解析的行: "大漠窮秋塞草衰，孤城落日鬬兵稀。",...
# 跳过无法解析的行: "身當恩遇常輕敵，力盡關山未解圍。",...
# 跳过无法解析的行: "鐵衣遠戍辛勤久，玉箸應啼別離後。",...
# 跳过无法解析的行: "少婦城南欲斷腸，征人薊北空回首。",...
# 跳过无法解析的行: "邊風飄飄那可度，絕域蒼茫更何有。",...
# 跳过无法解析的行: "殺氣三日作陣雲，寒聲一夜傳刁斗。",...
# 跳过无法解析的行: "相看白刃血紛紛，死節從來豈顧勳。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 燕歌行",...
# 跳过无法解析的行: "id": "09788f19-1e11-4394-a543-0edf2cfdcae9"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李頎",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "白日登山望烽火，昏黃飲馬傍交河。",...
# 跳过无法解析的行: "行人刁斗風砂暗，公主琵琶幽怨多。",...
# 跳过无法解析的行: "野營萬里無城郭，雨雪紛紛連大漠。",...
# 跳过无法解析的行: "胡雁哀鳴夜夜飛，胡兒眼淚雙雙落。",...
# 跳过无法解析的行: "聞道玉門猶被遮，應將性命逐輕車。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "生活",...
# 跳过无法解析的行: "冬天",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 從軍行",...
# 跳过无法解析的行: "id": "0ed53ef4-30ca-41ac-a629-d778e5cc2bfa"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "噫吁嚱！危乎高哉！蜀道之難難於上青天！蠶叢及魚鳧，開國何茫然。",...
# 跳过无法解析的行: "爾來四萬八千歲，乃與秦塞通人煙。",...
# 跳过无法解析的行: "西當太白有鳥道，可以橫絕峨眉巔。",...
# 跳过无法解析的行: "地崩山摧壯士死，然後天梯石棧方鉤連。",...
# 跳过无法解析的行: "上有六龍迴日之高標，下有衝波逆折之迴川。",...
# 跳过无法解析的行: "黃鶴之飛尚不得，猨猱欲度愁攀緣。",...
# 跳过无法解析的行: "青泥何盤盤，百步九折縈巖巒。",...
# 跳过无法解析的行: "捫參歷井仰脅息，以手撫膺坐長歎。",...
# 跳过无法解析的行: "問君西遊何時還？畏途巉巖不可攀。",...
# 跳过无法解析的行: "但見悲鳥號枯木，雄飛呼雌繞林間。",...
# 跳过无法解析的行: "又聞子規啼夜月，愁空山，蜀道之難難於上青天！使人聽此彫朱顏。",...
# 跳过无法解析的行: "連峰去天不盈尺，枯松倒挂倚絕壁。",...
# 跳过无法解析的行: "飛湍瀑流相喧豗，砅崖轉石萬壑雷。",...
# 跳过无法解析的行: "其嶮也若此，嗟爾遠道之人胡爲乎來哉？劒閣崢嶸而崔嵬，一夫當關，萬夫莫開。",...
# 跳过无法解析的行: "所守或匪親，化爲狼與豺。",...
# 跳过无法解析的行: "朝避猛虎，夕避長蛇。",...
# 跳过无法解析的行: "磨牙吮血，殺人如麻。",...
# 跳过无法解析的行: "錦城雖云樂，不如早還家。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "抒情",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 蜀道難",...
# 跳过无法解析的行: "id": "e117d224-39ca-4eba-a047-0d36ce8b8c26"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王昌齡",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "奉帚平明金殿開，暫將團扇共裴回。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 長信怨 二",...
# 跳过无法解析的行: "id": "1b6f2389-2d09-4d51-982a-e7efb35113c5"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "玉階生白露，夜久侵羅襪。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "孤独",...
# 跳过无法解析的行: "宫怨",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 玉階怨",...
# 跳过无法解析的行: "id": "f93545e7-747e-4d12-a6c8-e484c46b2860"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "秦地羅敷女，采桑綠水邊。",...
# 跳过无法解析的行: "素手青條上，紅妝白日鮮。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "清商曲辞",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 子夜四時歌四首 春歌",...
# 跳过无法解析的行: "id": "4e92a96d-aa74-4153-8314-b6df22d1e18a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鏡湖三百里，菡萏發荷花。",...
# 跳过无法解析的行: "五月西施采，人看隘若邪。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "清商曲辞",...
# 跳过无法解析的行: "夏天",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "哲理",...
# 跳过无法解析的行: "写人",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 子夜四時歌四首 夏歌",...
# 跳过无法解析的行: "id": "4bd5be2b-5788-42c0-a300-9d106a73d46e"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "長安一片月，萬戶擣衣聲。",...
# 跳过无法解析的行: "秋風吹不盡，總是玉關情。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "清商曲辞",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "月亮",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 子夜四時歌四首 秋歌",...
# 跳过无法解析的行: "id": "49194c4b-b775-4d21-a506-fc0a2ff308f1"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "明朝驛使發，一夜絮征袍。",...
# 跳过无法解析的行: "素手抽針冷，那堪把剪刀。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "清商曲辞",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: "冬天",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "相和歌辭 子夜四時歌四首 冬歌",...
# 跳过无法解析的行: "id": "35319d7e-9cf6-43b0-bfa3-991cf82a49f9"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟郊",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "梧桐相待老，鴛鴦會雙死。",...
# 跳过无法解析的行: "貞婦貴徇夫，舍生亦如此。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "赞颂",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "琴曲歌辭 列女操",...
# 跳过无法解析的行: "id": "7ccd9915-51a1-4748-9989-af243036455b"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "孟郊",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "慈母手中線，遊子身上衣。",...
# 跳过无法解析的行: "臨行密密縫，意恐遲遲歸。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "杂曲歌辞",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "母爱",...
# 跳过无法解析的行: "三年级下册",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 遊子吟",...
# 跳过无法解析的行: "id": "22923091-18da-429d-9ef1-6b367fd74b1a"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "杜甫",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "三月三日天氣新，長安水邊多麗人。",...
# 跳过无法解析的行: "態濃意遠淑且真，肌理細膩骨肉勻。",...
# 跳过无法解析的行: "繡羅衣裳照暮春，蹙金孔雀銀麒麟。",...
# 跳过无法解析的行: "頭上何所有？翠微㔩葉垂鬢脣。",...
# 跳过无法解析的行: "背後何所見？珠壓腰衱穩稱身。",...
# 跳过无法解析的行: "就中雲幕椒房親，賜名大國虢與秦。",...
# 跳过无法解析的行: "紫駞之峯出翠釜，水晶之盤行素鱗。",...
# 跳过无法解析的行: "犀筯厭飫久未下，鸞刀縷切空紛綸。",...
# 跳过无法解析的行: "黃門飛鞚不動塵，御廚絲絡送八珍。",...
# 跳过无法解析的行: "簫鼓哀吟感鬼神，賓從雜遝實要津。",...
# 跳过无法解析的行: "後來鞍馬何逡巡，當軒下馬入錦茵。",...
# 跳过无法解析的行: "楊花雪落覆白蘋，青鳥飛去銜紅巾。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "杂曲歌辞",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "讽刺",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 麗人行",...
# 跳过无法解析的行: "id": "aaae5882-9b74-4b45-9bb5-9f773a721119"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "長相思，在長安，絡緯秋啼金井欄。",...
# 跳过无法解析的行: "微霜淒淒簟色寒，孤燈不明思欲絕。",...
# 跳过无法解析的行: "卷帷望月空長歎，美人如花隔雲端。",...
# 跳过无法解析的行: "上有青冥之長天，下有綠水之波瀾。",...
# 跳过无法解析的行: "天長路遠魂飛苦，夢魂不到關山難。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "杂曲歌辞",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 長相思三首 一",...
# 跳过无法解析的行: "id": "d4baf2d1-ea61-4fb3-a284-e889275bdca2"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "日色已盡花含煙，月明欲素愁不眠。",...
# 跳过无法解析的行: "趙瑟初停鳳凰柱，蜀琴欲奏鴛鴦弦。",...
# 跳过无法解析的行: "此曲有意無人傳，願隨春風寄燕然，憶君迢迢隔青天。",...
# 跳过无法解析的行: "昔日橫波目，今成流淚泉。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 長相思三首 二",...
# 跳过无法解析的行: "id": "caa023cf-9f55-450c-9638-1cf5c0223cc1"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "金尊清酒斗十千，玉盤珍羞直萬錢。",...
# 跳过无法解析的行: "停杯投筯不能食，拔劒四顧心茫然。",...
# 跳过无法解析的行: "欲渡黃河冰塞川，將登太行雪暗天。",...
# 跳过无法解析的行: "閑來垂釣坐溪上，忽復乘舟夢日邊。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "黄河",...
# 跳过无法解析的行: "励志",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "八年级下册(课内)",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "宴饮",...
# 跳过无法解析的行: "哲理",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 行路難三首 一",...
# 跳过无法解析的行: "id": "527eba4b-b35c-4d29-99e7-8f40c6f3d5b7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "大道如青天，我獨不得出。",...
# 跳过无法解析的行: "羞逐長安社中兒，赤雞白狗賭梨栗。",...
# 跳过无法解析的行: "彈劒作歌奏苦聲，曳裾王門不稱情。",...
# 跳过无法解析的行: "淮陰市井笑韓信，漢朝公卿忌賈生。",...
# 跳过无法解析的行: "君不見昔時燕家重郭隗，擁篲折腰無嫌猜。",...
# 跳过无法解析的行: "劇辛樂毅感恩分，輸肝剖膽效英才。",...
# 跳过无法解析的行: "昭王白骨縈蔓草，誰人更掃黃金臺。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "失意",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 行路難三首 二",...
# 跳过无法解析的行: "id": "e12edd83-36cd-4e8a-a630-91874631c51f"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "有耳莫洗潁川水，有口莫食首陽蕨。",...
# 跳过无法解析的行: "含光混世貴無名，何用孤高比雲月。",...
# 跳过无法解析的行: "吾觀自古賢達人，功成不退皆殞身。",...
# 跳过无法解析的行: "子胥既棄吳江上，屈原終投湘水濱。",...
# 跳过无法解析的行: "陸機才多豈自保，李斯稅駕苦不早。",...
# 跳过无法解析的行: "華亭鶴唳詎可聞，上蔡蒼鷹何足道？君不見吳中張翰稱達士，秋風忽憶江東行。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "人生",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 行路難三首 三",...
# 跳过无法解析的行: "id": "b4f9c5b3-0108-4127-bf3e-73fd207176f3"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "崔顥",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "君家定何處？妾住在橫塘。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "孤独",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 長干曲四首 一",...
# 跳过无法解析的行: "id": "4bef9a5e-f4a1-44bd-a78c-cb0fe38ccdff"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "崔顥",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "家臨九江水，去來九江側。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "家乡",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: "热爱",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 長干曲四首 二",...
# 跳过无法解析的行: "id": "8d480633-1876-4082-aaca-a7b3a26c04d7"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "李白",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "妾髮初覆額，折花門前劇。",...
# 跳过无法解析的行: "郎騎竹馬來，遶牀弄青梅。",...
# 跳过无法解析的行: "同居長干里，兩小無嫌猜。",...
# 跳过无法解析的行: "十四爲君婦，羞顏尚不開。",...
# 跳过无法解析的行: "低頭向暗壁，千喚不一迴。",...
# 跳过无法解析的行: "十五始展眉，願同塵與灰。",...
# 跳过无法解析的行: "常存抱柱信，豈上望夫臺。",...
# 跳过无法解析的行: "十六君遠行，瞿塘灩預堆。",...
# 跳过无法解析的行: "五月不可觸，猨鳴天上哀。",...
# 跳过无法解析的行: "門前遲行跡，一一生綠苔。",...
# 跳过无法解析的行: "苔深不能掃，落葉秋風早。",...
# 跳过无法解析的行: "八月蝴蝶來，雙飛西園草。",...
# 跳过无法解析的行: "感此傷妾心，坐愁紅顏老。",...
# 跳过无法解析的行: "早晚下三巴，預將書報家。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 長干行二首 一",...
# 跳过无法解析的行: "id": "1352fbf1-2c3d-459c-b4ac-061e0c6befb8"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "沈佺期",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "盧家小婦鬱金堂，海燕雙栖玳瑁梁。",...
# 跳过无法解析的行: "九月寒砧催下葉，十年征戍憶遼陽。",...
# 跳过无法解析的行: "白狼河北音書斷，丹鳳城南秋夜長。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "闺怨",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 獨不見",...
# 跳过无法解析的行: "id": "15079155-e95e-4abc-b36e-f6b605848f37"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王涯",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "桂魄初生秋露微，輕羅已薄未更衣。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "秋天",...
# 跳过无法解析的行: "女子",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "雜曲歌辭 秋夜曲",...
# 跳过无法解析的行: "id": "1f66d2ec-8418-485e-a434-e21a0d439dda"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "皇甫冉",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "鶯啼燕語報新年，馬邑龍堆路幾千。",...
# 跳过无法解析的行: "家住秦城鄰漢苑，心隨明月到胡天。",...
# 跳过无法解析的行: "機中錦字論長恨，樓上花枝笑獨眠。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "思念",...
# 跳过无法解析的行: "七言律诗",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "妇女",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "春思",...
# 跳过无法解析的行: "id": "d35f583a-c20c-453c-a886-e13f98b2e4b4"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉方平",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "更深月色半人家，北斗闌干南斗斜。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "月亮",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "田园",...
# 跳过无法解析的行: "九年级上册(课外)",...
# 跳过无法解析的行: "中秋",...
# 跳过无法解析的行: "初中古诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "夜月",...
# 跳过无法解析的行: "id": "79e7ec6e-0d6c-4f95-8181-4671c42e1faf"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉方平",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "紗窗日落漸黃昏，金屋無人見淚痕。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "孤独",...
# 跳过无法解析的行: "七言绝句",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "春怨",...
# 跳过无法解析的行: "id": "fc1bc01d-c281-40fd-9e0d-4c484539e4ae"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王之渙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "白日依山盡，黃河入海流。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "黄河",...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "励志",...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "登楼",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "哲理",...
# 跳过无法解析的行: "名楼、庙宇",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "登鸛雀樓",...
# 跳过无法解析的行: "id": "63950163-6a10-4e74-af8a-09886e4ef2a8"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "王之渙",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "黃河遠上白雲間，一片孤城萬仞山。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "黄河",...
# 跳过无法解析的行: "山水",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: "乐府",...
# 跳过无法解析的行: "思乡",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "涼州詞二首 一",...
# 跳过无法解析的行: "id": "526d4ecc-e123-4b9d-a213-958bb947593d"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "劉眘虛",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "道由白雲盡，春與青溪長。",...
# 跳过无法解析的行: "時有落花至，遠隨流水香。",...
# 跳过无法解析的行: "閑門向山路，深柳讀書堂。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "春天",...
# 跳过无法解析的行: "写景",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "闕題",...
# 跳过无法解析的行: "id": "a2b4fe60-9809-422d-afa7-143a2088f045"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "柳中庸",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "歲歲金河復玉關，朝朝馬策與刀環。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "黄河",...
# 跳过无法解析的行: "边塞",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "征怨",...
# 跳过无法解析的行: "id": "92dd65da-8301-4c83-b8f3-986b6095c481"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "嚴維",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "故關衰草遍，離別正堪悲。",...
# 跳过无法解析的行: "路出寒雲外，人歸暮雪時。",...
# 跳过无法解析的行: "少孤爲客早，多難識君遲。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: "唐诗三百首",...
# 跳过无法解析的行: "冬天",...
# 跳过无法解析的行: "友情",...
# 跳过无法解析的行: "送别",...
# 跳过无法解析的行: "五言律诗",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "送李端",...
# 跳过无法解析的行: "id": "67c18ea1-db49-44b5-8b21-6176e4a86416"...
# 跳过无法解析的行: },...
# 跳过无法解析的行: {...
# 跳过无法解析的行: "author": "顧況",...
# 跳过无法解析的行: "paragraphs": [...
# 跳过无法解析的行: "玉樓天半起笙歌，風送宮嬪笑語和。",...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "tags": [...
# 跳过无法解析的行: ],...
# 跳过无法解析的行: "title": "宮詞五首 二",...
# 跳过无法解析的行: "id": "aa9f9e4d-aa34-496e-89cf-cfef61efa89d"...
# 跳过无法解析的行: }...
# 跳过无法解析的行: ]...
# 原始数据量: 732
#                 0
# 0    無人信高潔，誰爲表予心。
# 1            五言律诗
# 2  念天地之悠悠，獨愴然而涕下。
# 3            七言古诗
# 4    今看兩楹奠，當與夢時同。
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19960\1112035798.py in <module>
#      26 # 3. 数据清洗
#      27 # 清理正文：将段落列表合并成一个字符串
# ---> 28 df['content'] = df['paragraphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')
#      29
#      30 # 简单的文本清理，去除空格和特殊字符
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
#     390         return super().get_loc(key, method=method, tolerance=tolerance)
#     391
#
# KeyError: 'paragraphs'

# %%
import pandas as pd
from collections import Counter
import jieba

# 读取清洗后的数据
df = pd.read_csv('cleaned_tang_poems.csv')

# 定义停用词列表 (可以从网上下载中文停用词表)
stopwords = set(['，', '。', '？', '！', '的', '了', '在', '是', '我', '你', '他', '有', '和', '就', '不', '人', '都', '一', '上', '也', '很', '到', '说', '要', '去', '出', '会', '可', '以', '而', '之', '其', '为', '于', '与', '此', '何', '如', '为', '云', '曰', '兮', '矣', '也', '乎', '乃', '呜呼', '噫', '哉'])

def process_text(text):
    words = jieba.lcut(text)
    # 过滤掉单字和停用词
    words = [w for w in words if len(w) > 1 and w not in stopwords and not w.isspace()]
    return words

# 为所有诗分词
df['words'] = df['content'].apply(process_text)

# 按时期分组统计词频
for period, group in df.groupby('period'):
    all_words = [word for sublist in group['words'] for word in sublist]
    word_freq = Counter(all_words).most_common(20) # 取前20
    print(f"\n【{period}】高频词:")
    for word, freq in word_freq:
        print(f"{word}: {freq}")

# %%
import pandas as pd
from collections import Counter
import jieba

# 读取清洗后的数据
df = pd.read_csv('cleaned_tang_poems.csv')

# 定义停用词列表 (可以从网上下载中文停用词表)
stopwords = set(['，', '。', '？', '！', '的', '了', '在', '是', '我', '你', '他', '有', '和', '就', '不', '人', '都', '一', '上', '也', '很', '到', '说', '要', '去', '出', '会', '可', '以', '而', '之', '其', '为', '于', '与', '此', '何', '如', '为', '云', '曰', '兮', '矣', '也', '乎', '乃', '呜呼', '噫', '哉'])

def process_text(text):
    words = jieba.lcut(text)
    # 过滤掉单字和停用词
    words = [w for w in words if len(w) > 1 and w not in stopwords and not w.isspace()]
    return words

# 为所有诗分词
df['words'] = df['content'].apply(process_text)

# 按时期分组统计词频
for period, group in df.groupby('period'):
    all_words = [word for sublist in group['words'] for word in sublist]
    word_freq = Counter(all_words).most_common(20) # 取前20
    print(f"\n【{period}】高频词:")
    for word, freq in word_freq:
        print(f"{word}: {freq}")

# %%
from gensim import corpora, models

# 准备 LDA 需要的数据
dictionary = corpora.Dictionary(df['words'])
corpus = [dictionary.doc2bow(text) for text in df['words']]

# 训练 LDA 模型，假设我们找 5 个主题
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# 打印每个主题的关键词
for idx, topic in lda_model.print_topics(-1):
    print(f"主题 {idx}: {topic}")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx

# 1. 将分词结果合并为字符串
df['processed_content'] = df['words'].apply(' '.join)

# 2. 按诗人分组，合并他所有的诗
poet_corpus = df.groupby('author')['processed_content'].apply(' '.join).reset_index()

# 3. 计算 TF-IDF 向量
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(poet_corpus['processed_content'])

# 4. 计算诗人之间的余弦相似度
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# 5. 构建网络图
G = nx.Graph()
poets = poet_corpus['author'].tolist()

# 添加节点 (诗人)
for poet in poets:
    G.add_node(poet)

# 添加边 (相似度大于阈值)
threshold = 0.1 # 这个阈值可以调整
for i in range(len(poets)):
    for j in range(i+1, len(poets)):
        if cosine_sim[i, j] > threshold:
            G.add_edge(poets[i], poets[j], weight=cosine_sim[i, j])

# 保存为 Gephi 可读的格式
nx.write_gexf(G, 'poet_similarity_network.gexf')
print("诗人关系网络已保存为 'poet_similarity_network.gexf'，可用 Gephi 打开进行可视化。")

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>唐诗文风变化图谱</title>
    <script src="https://cdn.jsdelivr.net/npm/echarts@5.4.3/dist/echarts.min.js"></script>
</head>
<body>
    <div id="timeline" style="width: 1000px;height:600px;"></div>
    <script>
        // 这里需要你将 Python 分析出的“每个时期各类题材的数量”转换成如下格式的 JavaScript 数据
        // 例如： periods = ['初唐', '盛唐', '中唐', '晚唐']
        // seriesData = [ {name: '山水田园诗', type: 'line', data: [10, 25, 15, 5]}, ... ]
        
        // 初始化图表
        var chart = echarts.init(document.getElementById('timeline'));
        var option = {
            title: { text: '唐诗题材流变' },
            tooltip: { trigger: 'axis' },
            legend: { data: ['山水田园诗', '边塞诗', '咏物诗', '送别诗'] }, // 你的题材列表
            xAxis: { type: 'category', data: ['初唐', '盛唐', '中唐', '晚唐'] }, // 你的时期列表
            yAxis: { type: 'value' },
            series: seriesData // 这里放入你从 Python 计算好的数据
        };
        chart.setOption(option);
    </script>
</body>
</html>

# %%
# 计算时期-题材交叉表
period_genre_count = pd.crosstab(df['period'], df['genre'])
print(period_genre_count.to_json(force_ascii=False))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 生成全唐诗词云
all_text = ' '.join(df['content'])
wordcloud = WordCloud(font_path='simhei.ttf', # 指定中文字体路径
                      background_color='white',
                      width=800, height=600).generate(all_text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('wordcloud.png') # 保存图片
plt.show()

# %%
tang_poetry_project/
├── 唐诗三百首.json (原始数据)
├── data_cleaning.py
├── data_analysis.py
├── cleaned_tang_poems.csv
├── poet_similarity_network.gexf
├── wordcloud.png
├── timeline.html (单独的时间轴页面)
└── index.html (最终集大成的报告页面)
